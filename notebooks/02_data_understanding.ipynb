# %%
import  pandas as pd

df_1 = pd.read_csv('/Users/meetnakrani/Library/Mobile Documents/com~apple~CloudDocs/recommendation-engine-platform/data/raw/ml-32m/links.csv')
df_1.head()
df_1.shape
df_1.info()
print(f"df_1.describe(): {df_1.describe()}")
print(f"Number of null values in movieId: {df_1['movieId'].isnull().sum()}")
print(f'the percentage of null values in movieId: {df_1["movieId"].isnull().sum() / len(df_1) * 100}%')
print(f"Number of null values in imdbId: {df_1['imdbId'].isnull().sum()}")
print(f'the percentage of null values in imdbId: {df_1["imdbId"].isnull().sum() / len(df_1) * 100}%')
print(f"Number of null values in tmdbId: {df_1['tmdbId'].isnull().sum()}")
print(f'the percentage of null values in tmdbId: {round(df_1["tmdbId"].isnull().sum() / len(df_1) * 100, 2)}%')
print(f"Number of duplicated values in movieId: {df_1['movieId'].duplicated().sum()}")
print(f"Number of duplicated values in imdbId: {df_1['imdbId'].duplicated().sum()}")
print(f"Number of duplicated values in tmdbId: {df_1['tmdbId'].duplicated().sum()}")
print(f"Number of unique values in movieId: {df_1['movieId'].nunique()}")
print(f"Number of unique values in imdbId: {df_1['imdbId'].nunique()}")
print(f"Number of unique values in tmdbId: {df_1['tmdbId'].nunique()}")
print(f'filtering imdbId : {df_1[df_1["imdbId"] < 1000000]}')
print(f'minimum and maximum values of movieId: {df_1["movieId"].min()}, {df_1["movieId"].max()}')
print(f'minimum and maximum values of imdbId: {df_1["imdbId"].min()}, {df_1["imdbId"].max()}')

summary = pd.DataFrame({
    "Data Type": df_1.dtypes,
    "Null Count": df_1.isnull().sum(),
    "Null %": round(df_1.isnull().sum()/len(df_1)*100,2),
    "Unique Values": df_1.nunique()
})

print(summary)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 87585 entries, 0 to 87584
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   movieId  87585 non-null  int64
#  1   imdbId   87585 non-null  int64
#  2   tmdbId   87461 non-null  float64
# dtypes: float64(1), int64(2)
# memory usage: 2.0 MB
# df_1.describe():              movieId        imdbId        tmdbId
# count   87585.000000  8.758500e+04  8.746100e+04
# mean   157651.365519  2.792840e+06  2.413823e+05
# std     79013.402099  4.278866e+06  2.471467e+05
# min         1.000000  1.000000e+00  2.000000e+00
# 25%    112657.000000  9.464200e+04  4.683600e+04
# 50%    165741.000000  4.929960e+05  1.392720e+05
# 75%    213203.000000  3.877296e+06  3.816930e+05
# max    292757.000000  2.908110e+07  1.186337e+06
# Number of null values in movieId: 0
# the percentage of null values in movieId: 0.0%
# Number of null values in imdbId: 0
# the percentage of null values in imdbId: 0.0%
# Number of null values in tmdbId: 124
# the percentage of null values in tmdbId: 0.14%
# Number of duplicated values in movieId: 0
# Number of duplicated values in imdbId: 0
# Number of duplicated values in tmdbId: 159
# Number of unique values in movieId: 87585
# Number of unique values in imdbId: 87585
# Number of unique values in tmdbId: 87425
# filtering imdbId :        movieId  imdbId    tmdbId
# 0            1  114709     862.0
# 1            2  113497    8844.0
# 2            3  113228   15602.0
# 3            4  114885   31357.0
# 4            5  113041   11862.0
# ...        ...     ...       ...
# 87554   292529  311927  158144.0
# 87561   292585  985060  147230.0
# 87562   292593  210047   33589.0
# 87578   292629  116387   77552.0
# 87583   292755   64027  182776.0
#
# [46595 rows x 3 columns]
# minimum and maximum values of movieId: 1, 292757
# minimum and maximum values of imdbId: 1, 29081098
#         Data Type  Null Count  Null %  Unique Values
# movieId     int64           0    0.00          87585
# imdbId      int64           0    0.00          87585
# tmdbId    float64         124    0.14          87425

# %%
df_2 = pd.read_csv('/Users/meetnakrani/Library/Mobile Documents/com~apple~CloudDocs/recommendation-engine-platform/data/raw/ml-32m/movies.csv')
print(f'first of all main information of datasets :{df_2.head()}, {df_2.info()}, {df_2.describe()}')
print(
    f'The missing values in movieId: {df_2["movieId"].isnull().sum()}\n',
    f'The percentage of missing values in movieId: {round(df_2["movieId"].isnull().sum() / len(df_2) * 100, 2)}%'
)
print(
    f'The missing values in title: {df_2["title"].isnull().sum()}\n',
    f'The percentage of missing values in title: {round(df_2["title"].isnull().sum() / len(df_2) * 100, 2)}%'
)
print(
    f'The missing values in genres: {df_2["genres"].isnull().sum()}\n',
    f'The percentage of missing values in genres: {round(df_2["genres"].isnull().sum() / len(df_2) * 100, 2)}%'
)
print(
    f'checking duplicates value in title : {df_2["title"].duplicated().sum()} \n'
    f'checking duplicates vlaues in geners : {df_2["genres"].duplicated().sum()}'
)
print(
    f'chekinh unique values in movieId: {df_2["movieId"].nunique()} \n'
    f'checking unique value in title : {df_2["title"].nunique()} \n'
    f'checking unique vlaues in geners : {df_2["genres"].nunique()}'
)

# sorting values 
df_2["title_length"] = df_2["title"].str.len()

top_10 = (
    df_2.sort_values("title_length", ascending=False)
    [["title", "title_length"]]
    .head(10)
)

print("Top 10 Longest Movie Titles:")
print(top_10)

df_2["title_length"] = df_2["title"].str.len()

top_10 = (
    df_2.sort_values("title_length", ascending=True)
    [["title", "title_length"]]
    .head(10)
)

print("Top 10 sortest Movie Titles:")
print(top_10)

#extract relasing year 

df_2["year"] = df_2["title"].str.extract(r"\((\d{4})\)")


df_2["year"] = pd.to_numeric(df_2["year"], errors="coerce")


latest_year = df_2["year"].max()
oldest_year = df_2["year"].min()

print(f"Latest movie year in dataset: {latest_year}")

print("\nMovies released in the latest year:")
print(
    df_2[df_2["year"] == latest_year]
    [["title", "year"]]

)

print(f"\nOldest movie year in dataset: {oldest_year}")

print("\nMovies released in the oldest year:")
print(
    df_2[df_2["year"] == oldest_year]
    [["title", "year"]]
    
)


print(
    f'The values combinaation  in genres: {df_2["genres"].value_counts().head(20)}')

#finding number of geners in movie

df_2["genres_count"] = (df_2["genres"].str.split('|').apply(len))
print(df_2[["title","genres_count"]])

print(
    df_2.sort_values(
        "genres_count",
        ascending=True
    )[["title", "genres", "genres_count"]].head(4))

print(
    df_2.sort_values(
        "genres_count",
        ascending=False
    )[["title", "genres", "genres_count"]].head(4))

df_2.memory_usage(deep=True)

print(df_2.memory_usage(
    deep=True
).sum()/1024**2)

summary = pd.DataFrame({
    "Data Type": df_2.dtypes,
    "Null Count": df_2.isnull().sum(),
    "Null %": round(df_2.isnull().sum()/len(df_2)*100,2),
    "Unique Values": df_2.nunique()
})

print(summary)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 87585 entries, 0 to 87584
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   movieId  87585 non-null  int64
#  1   title    87585 non-null  object
#  2   genres   87585 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 2.0+ MB
# first of all main information of datasets :   movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy  , None,              movieId
# count   87585.000000
# mean   157651.365519
# std     79013.402099
# min         1.000000
# 25%    112657.000000
# 50%    165741.000000
# 75%    213203.000000
# max    292757.000000
# The missing values in movieId: 0
#  The percentage of missing values in movieId: 0.0%
# The missing values in title: 0
#  The percentage of missing values in title: 0.0%
# The missing values in genres: 0
#  The percentage of missing values in genres: 0.0%
# checking duplicates value in title : 203
# checking duplicates vlaues in geners : 85787
# chekinh unique values in movieId: 87585
# checking unique value in title : 87382
# checking unique vlaues in geners : 1798
# Top 10 Longest Movie Titles:
#                                                    title  title_length
# 9217   Godzilla, Mothra, and King Ghidorah: Giant Mon...           191
# 18206  Dragon Ball Z the Movie: The World's Strongest...           158
# 9179   Revolutionary Girl Utena: Adolescence of Utena...           145
# 13907  Extraordinary Adventures of Mr. West in the La...           143
# 65694  Lethal Kittens or how we came to Love our Shov...           140
# 6115   Lost Honor of Katharina Blum, The (Verlorene E...           134
# 5435   Nightmare City (a.k.a. City of the Walking Dea...           134
# 22479  More About the Children of Noisy Village (a.k....           130
# 7297   Love and Anarchy (Film d'amore e d'anarchia, o...           130
# 48072  Kino-pravda no. 18 - A Movie Camera Race over ...           128
# Top 10 sortest Movie Titles:
#       title  title_length
# 40753    6A             2
# 62639   过昭关             3
# 67953   Ava             3
# 85373   Zoe             3
# 62118   Eli             3
# 63270   Luz             3
# 55123   Tau             3
# 84925   Eva             3
# 56878  Wall             4
# 53110  Zero             4
# Latest movie year in dataset: 2023.0
#
# Movies released in the latest year:
#                                              title    year
# 84230  Asterix & Obelix: The Middle Kingdom (2023)  2023.0
# 84254                       The Blue Caftan (2023)  2023.0
# 84330                         Bad Behaviour (2023)  2023.0
# 84331                             Cassandro (2023)  2023.0
# 84333                                Eileen (2023)  2023.0
# ...                                            ...     ...
# 87576                         Flaming Cloud (2023)  2023.0
# 87577                     All Fun and Games (2023)  2023.0
# 87581                   Shelter in Solitude (2023)  2023.0
# 87582                                  Orca (2023)  2023.0
# 87584                    Race to the Summit (2023)  2023.0
#
# [952 rows x 2 columns]
#
# Oldest movie year in dataset: 1874.0
#
# Movies released in the oldest year:
#                          title    year
# 35829  Passage de Venus (1874)  1874.0
# The values combinaation  in genres: genres
# Drama                   12443
# Documentary              8132
# Comedy                   7761
# (no genres listed)       7080
# Comedy|Drama             3245
# Drama|Romance            2825
# Horror                   2487
# Comedy|Romance           2229
# Thriller                 1410
# Comedy|Drama|Romance     1335
# Drama|Thriller           1281
# Horror|Thriller          1242
# Crime|Drama              1150
# Animation                1120
# Drama|War                 818
# Action                    789
# Action|Drama              696
# Western                   686
# Crime|Drama|Thriller      655
# Romance                   645
# Name: count, dtype: int64
#                                     title  genres_count
# 0                        Toy Story (1995)             5
# 1                          Jumanji (1995)             3
# 2                 Grumpier Old Men (1995)             2
# 3                Waiting to Exhale (1995)             3
# 4      Father of the Bride Part II (1995)             1
# ...                                   ...           ...
# 87580           The Monroy Affaire (2022)             1
# 87581          Shelter in Solitude (2023)             2
# 87582                         Orca (2023)             1
# 87583              The Angry Breed (1968)             1
# 87584           Race to the Summit (2023)             3
#
# [87585 rows x 2 columns]
#                                title              genres  genres_count
# 43792  A Ghost in Monte Carlo (1990)             Romance             1
# 76940            The Embalmer (1965)              Horror             1
# 42954           Stolen Desire (1958)              Comedy             1
# 42955    Ten Thousand Talents (1960)  (no genres listed)             1
#                                                    title  \
# 15392                                      Rubber (2010)
# 4913                                     Motorama (1991)
# 8573   Wonderful World of the Brothers Grimm, The (1962)
# 70757                        Ico, the Brave Horse (1987)
#
#                                                   genres  genres_count
# 15392  Action|Adventure|Comedy|Crime|Drama|Film-Noir|...            10
# 4913   Adventure|Comedy|Crime|Drama|Fantasy|Mystery|S...             8
# 8573   Adventure|Animation|Children|Comedy|Drama|Fant...             8
# 70757  Adventure|Animation|Children|Drama|Fantasy|Mys...             7
# 15.61599063873291
#              Data Type  Null Count  Null %  Unique Values
# movieId          int64           0     0.0          87585
# title           object           0     0.0          87382
# genres          object           0     0.0           1798
# title_length     int64           0     0.0            125
# year           float64         615     0.7            142
# genres_count     int64           0     0.0              9

# %%
df_3 = pd.read_csv('/Users/meetnakrani/Library/Mobile Documents/com~apple~CloudDocs/recommendation-engine-platform/data/raw/ml-32m/ratings.csv')
print(f'the info of data is : {df_3.info()}')
print(f'the first 5 data is: {df_3.head()}')
print(f'the shape of  data is: {df_3.shape}')
print(f' data describe : {df_3.describe()}')


summary = pd.DataFrame({
    "Data Type": df_3.dtypes,
    "Missing Count": df_3.isnull().sum(),
    "Missing %": round(df_3.isnull().sum()/len(df_3)*100,2),
    "Unique Values": df_3.nunique()
})

print(summary)

print(f'dublicate values: {df_3.duplicated().sum()}')

#now for user analysis

print(f'the number of user: {df_3["userId"].unique()}')
print(f'most active users : {df_3["userId"].value_counts().head(10)}')

ratings_per_user = df_3.groupby("userId")["rating"].count()
print(ratings_per_user.describe())


#movie analysis
print(f'the number of rated movie: {df_3["movieId"].unique()}')
print(f'most rated  movies : {df_3["movieId"].value_counts().head(10)}')

rating_per_movie = df_3.groupby("movieId")["rating"].count()
print(rating_per_movie.describe())

#rating analysis
df_3["rating"].value_counts().sort_index()
print(f'avreage rating is: {df_3["rating"].mean()}')
print(f'median rating is: {df_3["rating"].median()}')

heighest_rated_movie = (df_3.groupby("rating")["movieId"].count()
                        .sort_index(ascending=False))
print(heighest_rated_movie.head(5))
print(heighest_rated_movie.tail(5))

#timestamp analysis
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32000204 entries, 0 to 32000203
# Data columns (total 4 columns):
#  #   Column     Dtype
# ---  ------     -----
#  0   userId     int64
#  1   movieId    int64
#  2   rating     float64
#  3   timestamp  int64
# dtypes: float64(1), int64(3)
# memory usage: 976.6 MB
# the info of data is : None
# the first 5 data is:    userId  movieId  rating  timestamp
# 0       1       17     4.0  944249077
# 1       1       25     1.0  944250228
# 2       1       29     2.0  943230976
# 3       1       30     5.0  944249077
# 4       1       32     5.0  943228858
# the shape of  data is: (32000204, 4)
#  data describe :              userId       movieId        rating     timestamp
# count  3.200020e+07  3.200020e+07  3.200020e+07  3.200020e+07
# mean   1.002785e+05  2.931861e+04  3.540396e+00  1.275241e+09
# std    5.794905e+04  5.095816e+04  1.058986e+00  2.561630e+08
# min    1.000000e+00  1.000000e+00  5.000000e-01  7.896520e+08
# 25%    5.005300e+04  1.233000e+03  3.000000e+00  1.051012e+09
# 50%    1.002970e+05  3.452000e+03  3.500000e+00  1.272622e+09
# 75%    1.504510e+05  4.419900e+04  4.000000e+00  1.503158e+09
# max    2.009480e+05  2.927570e+05  5.000000e+00  1.697164e+09
#           Data Type  Missing Count  Missing %  Unique Values
# userId        int64              0        0.0         200948
# movieId       int64              0        0.0          84432
# rating      float64              0        0.0             10
# timestamp     int64              0        0.0       25976523
# dublicate values: 0
# the number of user: [     1      2      3 ... 200946 200947 200948]
# most active users : userId
# 175325    33332
# 17035      9577
# 55653      9178
# 123465     9044
# 171795     9016
# 10202      7748
# 198515     7594
# 49305      7488
# 22744      7372
# 7858       7322
# Name: count, dtype: int64
# count    200948.000000
# mean        159.246193
# std         282.025462
# min          20.000000
# 25%          36.000000
# 50%          73.000000
# 75%         167.000000
# max       33332.000000
# Name: rating, dtype: float64
# the number of rated movie: [    17     25     29 ... 175771 157917 274343]
# most rated  movies : movieId
# 318     102929
# 356     100296
# 296      98409
# 2571     93808
# 593      90330
# 260      85010
# 2959     77332
# 480      75233
# 527      73849
# 4993     73122
# Name: count, dtype: int64
# count     84432.000000
# mean        379.005638
# std        2592.439791
# min           1.000000
# 25%           2.000000
# 50%           5.000000
# 75%          25.000000
# max      102929.000000
# Name: rating, dtype: float64
# avreage rating is: 3.5403956487277393
# median rating is: 3.5
# rating
# 5.0    4596577
# 4.5    2974000
# 4.0    8367654
# 3.5    4290105
# 3.0    6054990
# Name: movieId, dtype: int64
# rating
# 2.5    1685386
# 2.0    2028622
# 1.5     531063
# 1.0     946675
# 0.5     525132
# Name: movieId, dtype: int64

# %%
df_4 = pd.read_csv('/Users/meetnakrani/Library/Mobile Documents/com~apple~CloudDocs/recommendation-engine-platform/data/raw/ml-32m/tags.csv')
df_4.head()
df_4.shape
df_4.info()
df_4.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000072 entries, 0 to 2000071
# Data columns (total 4 columns):
#  #   Column     Dtype
# ---  ------     -----
#  0   userId     int64
#  1   movieId    int64
#  2   tag        object
#  3   timestamp  int64
# dtypes: int64(3), object(1)
# memory usage: 61.0+ MB
#              userId       movieId     timestamp
# count  2.000072e+06  2.000072e+06  2.000072e+06
# mean   8.192859e+04  7.189326e+04  1.528914e+09
# std    3.810650e+04  7.480379e+04  1.290835e+08
# min    2.200000e+01  1.000000e+00  1.135429e+09
# 25%    6.841300e+04  4.011000e+03  1.473615e+09
# 50%    7.821300e+04  5.232800e+04  1.574071e+09
# 75%    1.036980e+05  1.222940e+05  1.614740e+09
# max    1.622790e+05  2.926290e+05  1.697155e+09
